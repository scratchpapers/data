# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen 
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Scrape Data from ESPN NBA Standings 2019-2020 using BeautifulSoup

# %% [markdown]
# ### There are 2 URLs ( Both imported into Pandas and concatenated)
# #### 1. First is Regular Standings stats (url)
# #### 2. Second is the Expanded stats (url1)

# %% [markdown]
# ### 1 - Regular Stats (Standings tab)

# %%
url = 'http://www.espn.com/nba/standings/_/group/league'

# %%
page = urlopen(url).read()
page_soup = bs(page,'html.parser')
table = page_soup.findAll('tbody',{'class':'Table__TBODY'})

# %% [markdown]
# #### Getting Team Names

# %%
teamlink = table[0].find_all('div',{'class':'team-link'})
teaminfo = []

for team in teamlink:
    teamname = team.find('span',{'class':'hide-mobile'}).text
    teaminit = team.find('span',{'class':'show-mobile'}).text
    teaminfo.append([teamname, teaminit])

# %% [markdown]
# #### Getting Stats for Each Team

# %%
teamstat = []
statrows = table[1].findAll('tr',{'class':'Table__TR'}) #Stats Table with Individual Team stats
for statrow in statrows:
    row = statrow.findAll('td')
    won = row[0].text
    loss = row[1].text
    percent = row[2].text
    gamesbehind = row[3].text
    homerecord = row[4].text
    awayrecord = row[5].text
    divrecord = row[6].text
    confrecord = row[7].text
    ppg = row[8].text
    oppg = row[9].text
    diff = row[10].text
    winstreak = row[11].text
    last10 = row[12].text
    teamstat.append((won,loss,percent,gamesbehind,homerecord,awayrecord,
         divrecord,confrecord,ppg,oppg,diff,winstreak,last10))

# %% [markdown]
# #### Combine Teaminfo and Teamstats to create single list for each team with Labels

# %%
statlist =[]
for team,stats in zip(teaminfo,teamstat):
    statlist.append(team+list(stats))

labels = ['Team Name', 'Team Code', 'Win','Loss','% Win','Games Behind',
         'Home Record','Away Record','Division','Conference','PPG','Opp PPG',
         'PPG Difference','Win Streak','Last 10']

# %% [markdown]
# ### Import data into Pandas DataFrame and clean

# %%
df = pd.DataFrame(statlist,columns=labels)

# %% [markdown]
# #### Changing 'Games Behind' value for Milwaukee Bucks from a String Value '-' into INT value '0'

# %%
df.loc[0,('Games Behind')] = 0

# %% [markdown]
# #### Turning String Values into INT, FLOAT and NUMERIC Values

# %%
df[['Win','Loss']]=df[['Win','Loss']].astype(int)
df[['% Win','PPG','Opp PPG','Games Behind']] = df[['% Win','PPG','Opp PPG','Games Behind']].astype(float)
df['PPG Difference'] = pd.to_numeric(df['PPG Difference'])

# %% [markdown]
# #### Turning decimals in % Win column into percentage out of 100

# %%
df['% Win'] = df['% Win'] * 100

# %%
df.head()
# Out:
#             Team Name Team Code  Win  Loss  % Win  Games Behind Home Record  \
# 0     Milwaukee Bucks       MIL   53    12   81.5           0.0        28-3
# 1  Los Angeles Lakers       LAL   49    14   77.8           3.0        23-8
# 2     Toronto Raptors       TOR   46    18   71.9           6.5        23-9
# 3         LA Clippers       LAC   44    20   68.8           8.5        25-7
# 4      Boston Celtics       BOS   43    21   67.2           9.5        23-9
#
#   Away Record Division Conference    PPG  Opp PPG  PPG Difference Win Streak  \
# 0        25-9     13-1       34-5  118.6    107.4            11.2         L3
# 1        26-6      9-2       33-7  114.3    106.9             7.4         L1
# 2        23-9      8-4      30-10  113.0    106.5             6.5         W4
# 3       19-13      8-4      27-14  116.2    109.7             6.5         W1
# 4       20-12      7-6      27-10  113.0    106.8             6.2         W1
#
#   Last 10
# 0     6-4
# 1     8-2
# 2     6-4
# 3     7-3
# 4     5-5

# %% [markdown]
# ### 2 - Expanded Stats. Scraping the data, importing into Pandas and cleaning data.

# %%
url1 = 'https://www.espn.com/nba/standings/_/group/league/view/expanded'

# %%
page = urlopen(url1).read()
page_soup = bs(page,'html.parser')
table = page_soup.findAll('tbody',{'class':'Table__TBODY'})

# %%
statrows = table[1].findAll('tr',{'class':'Table__TR'})

# %%
teamlink = table[0].find_all('div',{'class':'team-link'})
teaminfo = []

for team in teamlink:
    teaminit = team.find('span',{'class':'show-mobile'}).text
    teaminfo.append([teaminit])

# %%
teamstat1 = []
#Stats Table with Individual Team stats
statrows = table[1].findAll('tr',{'class':'Table__TR'}) 
for statrow in statrows:
    row = statrow.findAll('td')
    Game_3PT = row[4].text
    Game_10PT = row[5].text
    vs500above = row[6].text
    vs500below = row[7].text
    teamstat1.append((Game_3PT, Game_10PT, vs500above, vs500below))

# %%
statlist1 =[]
for team,stats in zip(teaminfo,teamstat1):
    statlist1.append(team+list(stats))

labels1 = ['Team Code', '3 PT GAMES', '10 PT GAMES', 'VS. .500 And Above', 'VS. Below .500']

# %% [markdown]
# #### Import data into Pandas dataframe and clean

# %%
df1 = pd.DataFrame(statlist1,columns=labels1)

# %% [markdown]
# ### Calculating and appending Win % for each column
# #### * 3 PT GAMES = Record of games with final score difference of 3 points or less
# #### * 10 PT GAMES = Record of games with final score difference of 10 points or less
# #### * VS. .500 And Above = Record of games against teams with .500 average and above in season standing
# #### * VS. Below .500 = Record of games against teams with below .500 average in season standing

# %%
games3 = df1['3 PT GAMES'].str.split('-', n=1, expand=True)
games10 = df1['10 PT GAMES'].str.split('-', n=1, expand=True)
vs500above = df1['VS. .500 And Above'].str.split('-', n=1, expand=True)
vs500below = df1['VS. Below .500'].str.split('-',n=1,expand=True)

# %%
df1['3 PT GAMES % Won'] = round(games3[0].astype(int) *100 / (games3[0].astype(int)+games3[1].astype(int)),1)
df1['10 PT GAMES % Won'] = round(games10[0].astype(int) *100 / (games10[0].astype(int)+games10[1].astype(int)),1)
df1['VS .500 And Above % Won'] = round(vs500above[0].astype(int)*100 / (vs500above[0].astype(int)+vs500above[1].astype(int)),1)
df1['VS Below .500 % Won'] = round(vs500below[0].astype(int)*100 / (vs500below[0].astype(int)+vs500below[1].astype(int)),1)

# %%
df1 = df1[['Team Code','3 PT GAMES','3 PT GAMES % Won','10 PT GAMES','10 PT GAMES % Won','VS. .500 And Above','VS .500 And Above % Won','VS. .500 And Above','VS Below .500 % Won']]

# %%
df1.head()
# Out:
#   Team Code 3 PT GAMES  3 PT GAMES % Won 10 PT GAMES  10 PT GAMES % Won  \
# 0       MIL        3-1              75.0        36-7               83.7
# 1       LAL        5-3              62.5        25-7               78.1
# 2       TOR        6-4              60.0        21-9               70.0
# 3       LAC        8-1              88.9        29-8               78.4
# 4       BOS        5-5              50.0        26-7               78.8
#
#   VS. .500 And Above  VS .500 And Above % Won VS. .500 And Above  \
# 0              15-10                     60.0              15-10
# 1              17-10                     63.0              17-10
# 2              11-14                     44.0              11-14
# 3              17-11                     60.7              17-11
# 4              14-13                     51.9              14-13
#
#    VS Below .500 % Won
# 0                 95.0
# 1                 88.9
# 2                 89.7
# 3                 75.0
# 4                 78.4

# %% [markdown]
# ### Combining both dataframe into one. Using Merge and Join to concatenate

# %%
result = pd.merge(df, df1, on='Team Code', how='inner')

# %%
result
# Out:
#                  Team Name Team Code  Win  Loss  % Win  Games Behind  \
# 0          Milwaukee Bucks       MIL   53    12   81.5           0.0
# 1       Los Angeles Lakers       LAL   49    14   77.8           3.0
# 2          Toronto Raptors       TOR   46    18   71.9           6.5
# 3              LA Clippers       LAC   44    20   68.8           8.5
# 4           Boston Celtics       BOS   43    21   67.2           9.5
# 5           Denver Nuggets       DEN   43    22   66.2          10.0
# 6                Utah Jazz      UTAH   41    23   64.1          11.5
# 7               Miami Heat       MIA   41    24   63.1          12.0
# 8    Oklahoma City Thunder       OKC   40    24   62.5          12.5
# 9          Houston Rockets       HOU   40    24   62.5          12.5
# 10          Indiana Pacers       IND   39    26   60.0          14.0
# 11      Philadelphia 76ers       PHI   39    26   60.0          14.0
# 12        Dallas Mavericks       DAL   40    27   59.7          14.0
# 13       Memphis Grizzlies       MEM   32    33   49.2          21.0
# 14           Brooklyn Nets       BKN   30    34   46.9          22.5
# 15           Orlando Magic       ORL   30    35   46.2          23.0
# 16  Portland Trail Blazers       POR   29    37   43.9          24.5
# 17    New Orleans Pelicans        NO   28    36   43.8          24.5
# 18        Sacramento Kings       SAC   28    36   43.8          24.5
# 19       San Antonio Spurs        SA   27    36   42.9          25.0
# 20            Phoenix Suns       PHX   26    39   40.0          27.0
# 21      Washington Wizards       WSH   24    40   37.5          28.5
# 22       Charlotte Hornets       CHA   23    42   35.4          30.0
# 23           Chicago Bulls       CHI   22    43   33.8          31.0
# 24         New York Knicks        NY   21    45   31.8          32.5
# 25         Detroit Pistons       DET   20    46   30.3          33.5
# 26           Atlanta Hawks       ATL   20    47   29.9          34.0
# 27  Minnesota Timberwolves       MIN   19    45   29.7          33.5
# 28     Cleveland Cavaliers       CLE   19    46   29.2          34.0
# 29   Golden State Warriors        GS   15    50   23.1          38.0
#
#    Home Record Away Record Division Conference  ...  Win Streak  Last 10  \
# 0         28-3        25-9     13-1       34-5  ...          L3      6-4
# 1         23-8        26-6      9-2       33-7  ...          L1      8-2
# 2         23-9        23-9      8-4      30-10  ...          W4      6-4
# 3         25-7       19-13      8-4      27-14  ...          W1      7-3
# 4         23-9       20-12      7-6      27-10  ...          W1      5-5
# 5         25-8       18-14     10-1      26-13  ...          L1      5-5
# 6        21-10       20-13      5-5      21-16  ...          L1      5-5
# 7         27-5       14-19     10-4      28-10  ...          L1      6-4
# 8        20-13       20-11      7-4      25-15  ...          W3      8-2
# 9        22-10       18-14      7-4      25-17  ...          W1      6-4
# 10       21-11       18-15      8-7      24-18  ...          L1      7-3
# 11        29-2       10-24     11-4      26-16  ...          W1      5-5
# 12       19-15       21-12     10-3      25-15  ...          W1      6-4
# 13       18-15       14-18      4-7      19-22  ...          L1      4-6
# 14       18-14       12-20      6-9      20-21  ...          W3      5-5
# 15       16-15       14-20      9-5      19-18  ...          W3      6-4
# 16       18-14       11-23      4-8      16-26  ...          W1      4-6
# 17       13-19       15-17      3-8      17-25  ...          W2      5-5
# 18       14-17       14-19      7-5      20-20  ...          L1      7-3
# 19       16-14       11-22      4-6      15-21  ...          W1      5-5
# 20       13-22       13-17      5-9      15-27  ...          L1      4-6
# 21       16-16        8-24      5-9      17-23  ...          W1      4-6
# 22       10-21       13-21      2-7      16-24  ...          W1      4-6
# 23       14-20        8-23      7-9      15-28  ...          W1      3-7
# 24       11-22       10-23     2-11      15-28  ...          W1      4-6
# 25       11-22        9-24     5-10      12-31  ...          L5      1-9
# 26       14-20        6-27      6-7      11-32  ...          L1      4-6
# 27        8-24       11-21     2-10       9-30  ...          L3      3-7
# 28       11-25        8-21     4-10      12-32  ...          L1      4-6
# 29        8-26        7-24     2-11       9-34  ...          L1      3-7
#
#     3 PT GAMES 3 PT GAMES % Won 10 PT GAMES 10 PT GAMES % Won  \
# 0          3-1             75.0        36-7              83.7
# 1          5-3             62.5        25-7              78.1
# 2          6-4             60.0        21-9              70.0
# 3          8-1             88.9        29-8              78.4
# 4          5-5             50.0        26-7              78.8
# 5          8-4             66.7       16-10              61.5
# 6          6-4             60.0       18-10              64.3
# 7          6-3             66.7        21-9              70.0
# 8          7-6             53.8        15-8              65.2
# 9          4-5             44.4       20-12              62.5
# 10         5-7             41.7       17-10              63.0
# 11         5-4             55.6       18-14              56.2
# 12         2-9             18.2        23-7              76.7
# 13         3-3             50.0       16-19              45.7
# 14         6-6             50.0       15-17              46.9
# 15         5-4             55.6       16-17              48.5
# 16         6-3             66.7       16-18              47.1
# 17         2-5             28.6       16-13              55.2
# 18         6-8             42.9       10-15              40.0
# 19         9-6             60.0        9-12              42.9
# 20         2-8             20.0       10-18              35.7
# 21         1-4             20.0       12-20              37.5
# 22         9-8             52.9        5-25              16.7
# 23         6-6             50.0        7-19              26.9
# 24         7-6             53.8        8-21              27.6
# 25         4-6             40.0        9-26              25.7
# 26         1-5             16.7        8-29              21.6
# 27         3-4             42.9       10-21              32.3
# 28         5-5             50.0        6-28              17.6
# 29         1-3             25.0        8-30              21.1
#
#     VS. .500 And Above VS .500 And Above % Won  VS. .500 And Above  \
# 0                15-10                    60.0               15-10
# 1                17-10                    63.0               17-10
# 2                11-14                    44.0               11-14
# 3                17-11                    60.7               17-11
# 4                14-13                    51.9               14-13
# 5                15-11                    57.7               15-11
# 6                11-15                    42.3               11-15
# 7                14-10                    58.3               14-10
# 8                 9-17                    34.6                9-17
# 9                15-11                    57.7               15-11
# 10               11-15                    42.3               11-15
# 11               12-18                    40.0               12-18
# 12               10-16                    38.5               10-16
# 13                8-20                    28.6                8-20
# 14                9-19                    32.1                9-19
# 15                5-26                    16.1                5-26
# 16               10-21                    32.3               10-21
# 17                9-27                    25.0                9-27
# 18                9-21                    30.0                9-21
# 19               11-19                    36.7               11-19
# 20                7-21                    25.0                7-21
# 21                6-18                    25.0                6-18
# 22                5-22                    18.5                5-22
# 23                2-23                     8.0                2-23
# 24                5-24                    17.2                5-24
# 25                6-20                    23.1                6-20
# 26                6-25                    19.4                6-25
# 27                4-27                    12.9                4-27
# 28                5-27                    15.6                5-27
# 29                3-27                    10.0                3-27
#
#    VS Below .500 % Won
# 0                 95.0
# 1                 88.9
# 2                 89.7
# 3                 75.0
# 4                 78.4
# 5                 71.8
# 6                 78.9
# 7                 65.9
# 8                 81.6
# 9                 65.8
# 10                71.8
# 11                77.1
# 12                73.2
# 13                64.9
# 14                58.3
# 15                73.5
# 16                54.3
# 17                67.9
# 18                55.9
# 19                48.5
# 20                51.4
# 21                45.0
# 22                47.4
# 23                50.0
# 24                43.2
# 25                35.0
# 26                38.9
# 27                45.5
# 28                42.4
# 29                34.3
#
# [30 rows x 23 columns]

# %% [markdown]
# ### Checking some stats and getting the list of column names in dataframe to see what we can work with

# %%
result.describe()
# Out:
#              Win       Loss      % Win  Games Behind         PPG     Opp PPG  \
# count  30.000000  30.000000  30.000000     30.000000   30.000000   30.000000
# mean   32.366667  32.366667  50.090000     20.500000  111.463333  111.430000
# std    10.423724  10.749445  16.343202     10.576487    3.909271    3.993715
# min    15.000000  12.000000  23.100000      0.000000  102.900000  106.500000
# 25%    23.250000  24.000000  35.925000     12.125000  109.075000  107.525000
# 50%    30.000000  34.500000  46.550000     22.750000  112.000000  110.550000
# 75%    40.750000  41.500000  62.950000     29.625000  113.525000  114.700000
# max    53.000000  50.000000  81.500000     38.000000  118.600000  119.700000
#
#        PPG Difference  3 PT GAMES % Won  10 PT GAMES % Won  \
# count       30.000000         30.000000          30.000000
# mean         0.033333         48.953333          49.913333
# std          5.106340         17.422176          20.612981
# min         -8.700000         16.700000          16.700000
# 25%         -3.475000         42.000000          33.150000
# 50%         -0.850000         50.000000          47.800000
# 75%          3.250000         60.000000          64.975000
# max         11.200000         88.900000          83.700000
#
#        VS .500 And Above % Won  VS Below .500 % Won
# count                30.000000            30.000000
# mean                 34.216667            62.316667
# std                  16.681335            17.146410
# min                   8.000000            34.300000
# 25%                  20.325000            47.675000
# 50%                  32.200000            65.350000
# 75%                  43.575000            74.625000
# max                  63.000000            95.000000

# %% [markdown]
# ### Looks like we can work with these as they are numerical values

# %%
finaldf = result[['Team Name', 'Team Code','Win', 'Loss','% Win','Games Behind','PPG','Opp PPG','PPG Difference','3 PT GAMES % Won','10 PT GAMES % Won','VS .500 And Above % Won','VS Below .500 % Won']].set_index('Team Code')

# %%
finaldf
# Out:
#                         Team Name  Win  Loss  % Win  Games Behind    PPG  \
# Team Code
# MIL               Milwaukee Bucks   53    12   81.5           0.0  118.6
# LAL            Los Angeles Lakers   49    14   77.8           3.0  114.3
# TOR               Toronto Raptors   46    18   71.9           6.5  113.0
# LAC                   LA Clippers   44    20   68.8           8.5  116.2
# BOS                Boston Celtics   43    21   67.2           9.5  113.0
# DEN                Denver Nuggets   43    22   66.2          10.0  110.4
# UTAH                    Utah Jazz   41    23   64.1          11.5  111.0
# MIA                    Miami Heat   41    24   63.1          12.0  112.2
# OKC         Oklahoma City Thunder   40    24   62.5          12.5  110.8
# HOU               Houston Rockets   40    24   62.5          12.5  118.1
# IND                Indiana Pacers   39    26   60.0          14.0  109.3
# PHI            Philadelphia 76ers   39    26   60.0          14.0  109.6
# DAL              Dallas Mavericks   40    27   59.7          14.0  116.4
# MEM             Memphis Grizzlies   32    33   49.2          21.0  112.6
# BKN                 Brooklyn Nets   30    34   46.9          22.5  110.8
# ORL                 Orlando Magic   30    35   46.2          23.0  106.4
# POR        Portland Trail Blazers   29    37   43.9          24.5  113.6
# NO           New Orleans Pelicans   28    36   43.8          24.5  116.2
# SAC              Sacramento Kings   28    36   43.8          24.5  109.0
# SA              San Antonio Spurs   27    36   42.9          25.0  113.2
# PHX                  Phoenix Suns   26    39   40.0          27.0  112.6
# WSH            Washington Wizards   24    40   37.5          28.5  115.6
# CHA             Charlotte Hornets   23    42   35.4          30.0  102.9
# CHI                 Chicago Bulls   22    43   33.8          31.0  106.8
# NY                New York Knicks   21    45   31.8          32.5  105.8
# DET               Detroit Pistons   20    46   30.3          33.5  107.2
# ATL                 Atlanta Hawks   20    47   29.9          34.0  111.8
# MIN        Minnesota Timberwolves   19    45   29.7          33.5  113.3
# CLE           Cleveland Cavaliers   19    46   29.2          34.0  106.9
# GS          Golden State Warriors   15    50   23.1          38.0  106.3
#
#            Opp PPG  PPG Difference  3 PT GAMES % Won  10 PT GAMES % Won  \
# Team Code
# MIL          107.4            11.2              75.0               83.7
# LAL          106.9             7.4              62.5               78.1
# TOR          106.5             6.5              60.0               70.0
# LAC          109.7             6.5              88.9               78.4
# BOS          106.8             6.2              50.0               78.8
# DEN          107.4             3.0              66.7               61.5
# UTAH         107.9             3.1              60.0               64.3
# MIA          108.9             3.3              66.7               70.0
# OKC          108.3             2.5              53.8               65.2
# HOU          114.4             3.7              44.4               62.5
# IND          107.4             1.9              41.7               63.0
# PHI          107.4             2.2              55.6               56.2
# DAL          110.3             6.1              18.2               76.7
# MEM          113.7            -1.1              50.0               45.7
# BKN          111.4            -0.6              50.0               46.9
# ORL          107.3            -0.9              55.6               48.5
# POR          115.3            -1.7              66.7               47.1
# NO           117.0            -0.8              28.6               55.2
# SAC          110.9            -1.9              42.9               40.0
# SA           114.9            -1.7              60.0               42.9
# PHX          113.9            -1.3              20.0               35.7
# WSH          119.6            -4.0              20.0               37.5
# CHA          109.6            -6.7              52.9               16.7
# CHI          109.9            -3.1              50.0               26.9
# NY           112.3            -6.5              53.8               27.6
# DET          110.8            -3.6              40.0               25.7
# ATL          119.7            -7.9              16.7               21.6
# MIN          117.5            -4.2              42.9               32.3
# CLE          114.8            -7.9              50.0               17.6
# GS           115.0            -8.7              25.0               21.1
#
#            VS .500 And Above % Won  VS Below .500 % Won
# Team Code
# MIL                           60.0                 95.0
# LAL                           63.0                 88.9
# TOR                           44.0                 89.7
# LAC                           60.7                 75.0
# BOS                           51.9                 78.4
# DEN                           57.7                 71.8
# UTAH                          42.3                 78.9
# MIA                           58.3                 65.9
# OKC                           34.6                 81.6
# HOU                           57.7                 65.8
# IND                           42.3                 71.8
# PHI                           40.0                 77.1
# DAL                           38.5                 73.2
# MEM                           28.6                 64.9
# BKN                           32.1                 58.3
# ORL                           16.1                 73.5
# POR                           32.3                 54.3
# NO                            25.0                 67.9
# SAC                           30.0                 55.9
# SA                            36.7                 48.5
# PHX                           25.0                 51.4
# WSH                           25.0                 45.0
# CHA                           18.5                 47.4
# CHI                            8.0                 50.0
# NY                            17.2                 43.2
# DET                           23.1                 35.0
# ATL                           19.4                 38.9
# MIN                           12.9                 45.5
# CLE                           15.6                 42.4
# GS                            10.0                 34.3

# %% [markdown]
# ## Using Seaborn to Plot Relationship Between Stats
# ### Seaborn Bar Plot showing Team Code and Winning Percentage with Horizontal Line showing 50% winning threshold

# %%
teams = [i.split(' ')[-1] for i in finaldf['Team Name']]

# %%
finaldf.index.name
# Out:
# 'Team Code'

# %%
fig = plt.figure(figsize=(20,10))
plt.xticks(rotation=75)
plt.rcParams['axes.labelsize'] = 40
plt.title("2019-20 NBA Standings with 50% Winning percentage line", size=24)
sns.set(style="whitegrid")
sns.barplot(data=finaldf, x=finaldf.index,y='% Win', palette='Paired').axhline(50)

# %% [markdown]
# ### According to the current standings, there are 13 teams who has 50% and above winning percentage

# %% [markdown]
# ## 1) What is the relationship between Team Win % and 3 PT Games % Win?
# ### - How do teams with high % win do in very close games where game is decided by 3 points or less?
# ### - How important is the winning those very close games?

# %%
fig = plt.figure(figsize=(9,10))
s = finaldf['Win']
plt.title("Team's season Win % vs 3 PT or less games Won %", size=24)
plt.rcParams['axes.labelsize'] = 40
ax = sns.scatterplot(x="% Win", y="3 PT GAMES % Won", data=finaldf, hue=finaldf.index, size=s, sizes=(40,300))
ax.legend(loc='center left', bbox_to_anchor=(1.25,0.5), ncol=1)
for line in range(0,len(finaldf['Team Name'])):
     ax.text(finaldf['% Win'][line]+0.01, finaldf['3 PT GAMES % Won'][line], 
     finaldf.index[line], horizontalalignment='left', 
     size='medium', color='black', weight='semibold')

# %% [markdown]
# ### This scatterplot shows that the teams with higher season win % has overall higher close game winning percentage. Although there are cases of teams with high close game win percentage, the trend shows that better teams tend to win more close games.
#
# ### In addition, teams with around 70% or more win percentage wins 60% or more on all close games decided within 3 points. Since close games tend to have some luck involved, one can say that if the conditions were slightly changed, these winning teams could end up having a losing record very easily.

# %% [markdown]
# ## 2) How about games where the final score is within 10 points?

# %%
fig = plt.figure(figsize=(9,10))
s=finaldf['Win']
plt.rcParams['axes.labelsize'] = 20
plt.title("Team's season Win % vs 10 PT or less games Won %", size=24)
ax = sns.scatterplot(x="% Win", y="10 PT GAMES % Won", data=finaldf, hue=finaldf.index, size=s, sizes=(40,300))
ax.legend(loc='center left', bbox_to_anchor=(1.25,0.5), ncol=1)
for line in range(0,len(finaldf['Team Name'])):
     ax.text(finaldf['% Win'][line]+0.01, finaldf['10 PT GAMES % Won'][line], 
     finaldf.index[line], horizontalalignment='left', 
     size='small', color='black', weight='semibold')

# %% [markdown]
# ### This plot shows the relationship between Season Win % and Winning % of games where it was decided by 10 points or less. The size of the bubble is determined by the Win column, the more wins a team has the bigger the bubble.
#
# #### It shows that teams with 50% or more season win percentage, win 55% or more of all the games where it's several possession

# %% [markdown]
# ## 3) Is there a relationship between points per game scored vs Win %?
#
# ### Some teams can play some games really well by scoring high but lose more games by scoring much less points. This would show the team has high points per game but its Win % would be low

# %%
fig = plt.figure(figsize=(9,10))
plt.rcParams['axes.labelsize'] = 25
ax = sns.regplot(x="PPG Difference", y="% Win", marker='+', data=finaldf, scatter_kws={"color":'green'}, line_kws={'color':'blue'})
plt.title("Points Per Game Difference (PPG Difference) vs Season Win %", size=24)
for line in range(0,len(finaldf['Team Name'])):
     ax.text(finaldf['PPG Difference'][line]+0.01, finaldf['% Win'][line], 
     finaldf.index[line], horizontalalignment='left', 
     size='medium', color='black', weight='semibold')

# %% [markdown]
# ### This Regression plot shows a Linear relationship between a team's season Win % vs season average Points Per Game differences (PPG Difference)
# #### * This shows that teams with higher % of season win on average win by a higher margin of score on each game
# #### * It also shows that teams that have around 50% season Win % lose only by a margin of 1.5 points or less. The teams in this part of the chart has a high chance of improving their season next year.

# %% [markdown]
# ### This project was done to show my abilities in using Python, BeautifulSoup, and Pandas.

# %% [markdown]
# ## 1) Data was scraped from ESPN using BeautifulSoup and Python
# ## 2) Data was imported into Pandas and cleaned
# ## 3) Using Seaborn, various data analysis was made in addition to creating plots such as Scatterplot and Regression plot

# %% [markdown]
# ## Further analysis can be done using this dataset but this project was just to show a sample of work that can be done. Interesting project would be to scrape all player data or gameplay data and doing further analysis. Machine Learning can be used to predict what kind of attributes will give an insight into how a player will play in the future
